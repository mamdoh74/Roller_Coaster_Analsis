# %%
import pandas as pd
import numpy as np 
import matplotlib.pylab as plt
import seaborn as sns

# %%
## pd.set_option('max_columns' , 20)
plt.style.use('ggplot')

# %% [markdown]
# # Exploring the dataset

# %%
data = pd.read_csv(r'C:\Users\moham\Desktop\ \Bi Work\My Work\Data analysis with python\Project 2 _ Roller Coster dataset\Coaster_db.csv')

# %%
data.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model  ...  speed1  \
# ...

# %%
data.shape
# Out:
# (1087, 56)

# %%
data.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
data.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
data.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# like
# - subset my data to a small data that i can analysis and it willhold only the relevent data
# - rename columns
# - remove unneeded data
# - remove duplicates

# %%
# first thing i need to do is display the columns and chose what data i will chose to be in my subset 
data1 = data[['coaster_name', 'Manufacturer','opening_date_clean','speed_mph','height_ft','year_introduced', 'latitude', 'longitude',
       'Location', 'Status'
       #'Type', , 'Height restriction', 'Model', 'Height',
       #'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
       #'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
       #'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
       #'Track layout', 'Fastrack available', 'Soft opening date.1',
      # 'Closing date', 'Opened', 'Replaced by', 'Website',
      # 'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
     #  'Single rider line available', 'Restraint Style',
      # 'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
      # 'year_introduced', 'latitude', 'longitude', 'Type_Main',
      # , 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       #, 'height_value', 'height_unit', 'height_ft',
       ,'Inversions_clean', 'Gforce_clean']]

# %%
data1
# Out:
#                                 coaster_name                 Manufacturer  \
# 0                         Switchback Railway       LaMarcus Adna Thompson
# 1                          Flip Flap Railway                 Lina Beecher
# 2     Switchback Railway (Euclid Beach Park)                          NaN
# 3               Loop the Loop (Coney Island)               Edwin Prescott
# 4               Loop the Loop (Young's Pier)               Edwin Prescott
# ...                                      ...                          ...
# 1082                 American Dreier Looping            Anton Schwarzkopf
# 1083               Pantheon (roller coaster)                      Intamin
# 1084               Tron Lightcycle Power Run                       Vekoma
# 1085                                 Tumbili    S&S – Sansei Technologies
# 1086          Wonder Woman Flight of Courage  Rocky Mountain Construction
#
#      opening_date_clean  speed_mph  height_ft  year_introduced  latitude  \
# ...

# %%
# or i can use another way by dropping the data like 
data.drop(['dType', 'Height restriction', 'Model', 'Height','Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section'] , axis =1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [78], in <cell line: 2>()
#       1 # or i can use another way by dropping the data like
# ----> 2 data.drop(['dType', 'Height restriction', 'Model', 'Height','Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section'] , axis =1)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
data

# %%
# i will work with data1

# %% [markdown]
# #### changing the data types of columns

# %%
data1['opening_date_clean']
# Out:
# 0       1884-06-16
# 1       1895-01-01
# 2              NaN
# 3       1901-01-01
# 4       1901-01-01
#            ...
# 1082           NaN
# 1083    2022-01-01
# 1084    2016-06-16
# 1085           NaN
# 1086    2022-01-01
# Name: opening_date_clean, Length: 1087, dtype: object

# %% [markdown]
# here i notice that the data type of the opening data clean is object not date so i will chnage it to date

# %%
pd.to_datetime(data1['opening_date_clean'])
# Out:
# 0      1884-06-16
# 1      1895-01-01
# 2             NaT
# 3      1901-01-01
# 4      1901-01-01
#           ...
# 1082          NaT
# 1083   2022-01-01
# 1084   2016-06-16
# 1085          NaT
# 1086   2022-01-01
# Name: opening_date_clean, Length: 1087, dtype: datetime64[ns]

# %%
# here i should assing the value of my date to this date like 
data1['opening_date_clean'] = pd.to_datetime(data1['opening_date_clean'])
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_36952\2555811633.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['opening_date_clean'] = pd.to_datetime(data1['opening_date_clean'])

# %%
data1.dtypes
# Out:
# coaster_name                  object
# Manufacturer                  object
# opening_date_clean    datetime64[ns]
# speed_mph                    float64
# height_ft                    float64
# year_introduced                int64
# latitude                     float64
# longitude                    float64
# Location                      object
# Status                        object
# Inversions_clean               int64
# Gforce_clean                 float64
# dtype: object

# %% [markdown]
# to change to numeric value i should

# %%
data1['year_introduced']=pd.to_numeric(data1['year_introduced'])
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_36952\2538129603.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['year_introduced']=pd.to_numeric(data1['year_introduced'])

# %% [markdown]
# ### Rename columns

# %%
data1=data1.rename(columns={'coaster_name' :'Coaster_Name', 
                      'Manufacturer':'Manufactur', 
                      'opening_date_clean':'Opening_Date_clean', 
                      'speed_mph':'Speed_mph',
                       'height_ft':'Height_ft', 
                      'year_introduced':'Year_Introduced', })

# %%
data1.columns
# Out:
# Index(['Coaster_Name', 'Manufactur', 'Opening_Date_clean', 'Speed_mph',
#        'Height_ft', 'Year_Introduced', 'latitude', 'longitude', 'Location',
#        'Status', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %% [markdown]
# ##### explore the missing valeus

# %%
data1.isna().sum()
# Out:
# Coaster_Name            0
# Manufactur             59
# Opening_Date_clean    250
# Speed_mph             150
# Height_ft             916
# Year_Introduced         0
# latitude              275
# longitude             275
# Location                0
# Status                213
# Inversions_clean        0
# Gforce_clean          725
# dtype: int64

# %%
data1.duplicated
# Out:
# <bound method DataFrame.duplicated of                                 Coaster_Name                   Manufactur  \
# 0                         Switchback Railway       LaMarcus Adna Thompson
# 1                          Flip Flap Railway                 Lina Beecher
# 2     Switchback Railway (Euclid Beach Park)                          NaN
# 3               Loop the Loop (Coney Island)               Edwin Prescott
# 4               Loop the Loop (Young's Pier)               Edwin Prescott
# ...                                      ...                          ...
# 1082                 American Dreier Looping            Anton Schwarzkopf
# 1083               Pantheon (roller coaster)                      Intamin
# 1084               Tron Lightcycle Power Run                       Vekoma
# 1085                                 Tumbili    S&S – Sansei Technologies
# 1086          Wonder Woman Flight of Courage  Rocky Mountain Construction
#
# ...

# %%
data1.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082    False
# 1083    False
# 1084    False
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
# to show the sum of duplicated rows 
data1.duplicated().sum()
# Out:
# 0

# %%
# to show the duplicated rows 
data1[data1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Coaster_Name, Manufactur, Opening_Date_clean, Speed_mph, Height_ft, Year_Introduced, latitude, longitude, Location, Status, Inversions_clean, Gforce_clean]
# Index: []

# %%
data1.loc[data1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Coaster_Name, Manufactur, Opening_Date_clean, Speed_mph, Height_ft, Year_Introduced, latitude, longitude, Location, Status, Inversions_clean, Gforce_clean]
# Index: []

# %%
data1.loc[data1.duplicated(subset=['Coaster_Name'])]
# Out:
#                             Coaster_Name  \
# 43                 Crystal Beach Cyclone
# 60                           Derby Racer
# 61           Blue Streak (Conneaut Lake)
# 167        Big Thunder Mountain Railroad
# 237    Thunder Run (Canada's Wonderland)
# ...                                  ...
# 1063                  Lil' Devil Coaster
# 1064  Little Dipper (Conneaut Lake Park)
# 1080                          Iron Gwazi
# 1082             American Dreier Looping
# 1084           Tron Lightcycle Power Run
#
#                                              Manufactur Opening_Date_clean  \
# 43                                   Traver Engineering         1926-01-01
# 60                                       Fred W. Pearce         1911-01-01
# 61                                                  NaN         1938-05-23
# 167   Arrow Development (California and Florida)Dyna...                NaT
# 237                                          Mack Rides         1981-05-23
# ...

# %%
data1.query('Coaster_Name == "Crystal Beach Cyclone"')
# Out:
#              Coaster_Name          Manufactur Opening_Date_clean  Speed_mph  \
# 39  Crystal Beach Cyclone  Traver Engineering         1926-01-01       60.0
# 43  Crystal Beach Cyclone  Traver Engineering         1926-01-01       60.0
#
#     Height_ft  Year_Introduced  latitude  longitude            Location  \
# 39        NaN             1926   42.8617   -79.0598  Crystal Beach Park
# 43        NaN             1927   42.8617   -79.0598  Crystal Beach Park
#
#      Status  Inversions_clean  Gforce_clean
# 39  Removed                 0           4.0
# 43  Removed                 0           4.0

# %%
data1.loc[data1.duplicated(subset=['Coaster_Name','Manufactur','Location','Opening_Date_clean'])]
# Out:
#                             Coaster_Name  \
# 43                 Crystal Beach Cyclone
# 60                           Derby Racer
# 61           Blue Streak (Conneaut Lake)
# 167        Big Thunder Mountain Railroad
# 237    Thunder Run (Canada's Wonderland)
# ...                                  ...
# 1063                  Lil' Devil Coaster
# 1064  Little Dipper (Conneaut Lake Park)
# 1080                          Iron Gwazi
# 1082             American Dreier Looping
# 1084           Tron Lightcycle Power Run
#
#                                              Manufactur Opening_Date_clean  \
# 43                                   Traver Engineering         1926-01-01
# 60                                       Fred W. Pearce         1911-01-01
# 61                                                  NaN         1938-05-23
# 167   Arrow Development (California and Florida)Dyna...                NaT
# 237                                          Mack Rides         1981-05-23
# ...

# %%
data1 = data1.loc[~data1.duplicated(subset=['Coaster_Name','Manufactur','Location','Opening_Date_clean'])].copy()

# %%
data1
# Out:
#                                 Coaster_Name                   Manufactur  \
# 0                         Switchback Railway       LaMarcus Adna Thompson
# 1                          Flip Flap Railway                 Lina Beecher
# 2     Switchback Railway (Euclid Beach Park)                          NaN
# 3               Loop the Loop (Coney Island)               Edwin Prescott
# 4               Loop the Loop (Young's Pier)               Edwin Prescott
# ...                                      ...                          ...
# 1079            Ice Breaker (roller coaster)                Premier Rides
# 1081                   Leviathan (Sea World)           Martin & Vleminckx
# 1083               Pantheon (roller coaster)                      Intamin
# 1085                                 Tumbili    S&S – Sansei Technologies
# 1086          Wonder Woman Flight of Courage  Rocky Mountain Construction
#
#      Opening_Date_clean  Speed_mph  Height_ft  Year_Introduced  latitude  \
# ...

# %%
data1.reset_index(drop = True)
# Out:
#                                Coaster_Name                   Manufactur  \
# 0                        Switchback Railway       LaMarcus Adna Thompson
# 1                         Flip Flap Railway                 Lina Beecher
# 2    Switchback Railway (Euclid Beach Park)                          NaN
# 3              Loop the Loop (Coney Island)               Edwin Prescott
# 4              Loop the Loop (Young's Pier)               Edwin Prescott
# ..                                      ...                          ...
# 985            Ice Breaker (roller coaster)                Premier Rides
# 986                   Leviathan (Sea World)           Martin & Vleminckx
# 987               Pantheon (roller coaster)                      Intamin
# 988                                 Tumbili    S&S – Sansei Technologies
# 989          Wonder Woman Flight of Courage  Rocky Mountain Construction
#
#     Opening_Date_clean  Speed_mph  Height_ft  Year_Introduced  latitude  \
# ...

# %% [markdown]
# ### now our data is cleaned and ready to analysis step

# %% [markdown]
# ### First thing we will do is
# # Feature understanding
# to under stand what is the distripution of there features or if there is any outliers in the data set
# callled ### univarient analysis

# %%
## first function is value_counts()
data1['Year_Introduced'].value_counts()
# Out:
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1956     1
# 1959     1
# 1961     1
# 1895     1
# 1884     1
# Name: Year_Introduced, Length: 101, dtype: int64

# %%
## shwoing this values in a plot 
data1['Year_Introduced'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: >

# %%
## shwoing this values in a plot 
data1['Year_Introduced'].value_counts().head(10).plot(kind='bar' , title ='years of coasters top 10')
# Out:
# <Axes: title={'center': 'years of coasters top 10'}>

# %%
ax = data1['Year_Introduced'].value_counts().head(10).plot(kind='bar' , title ='years of coasters top 10')
ax.set_xlabel('year')
ax.set_ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
data1['Speed_mph'].plot(kind='hist', bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
 data1['Speed_mph'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# now it is time to understand how are the different columns are related to each other
# # Feature Relationship

# %%
data1.plot(kind='scatter' , x='Speed_mph' , y ='Height_ft' , title='Relation between speed and height')
plt.show()

# %%
data1
# Out:
#                                 Coaster_Name                   Manufactur  \
# 0                         Switchback Railway       LaMarcus Adna Thompson
# 1                          Flip Flap Railway                 Lina Beecher
# 2     Switchback Railway (Euclid Beach Park)                          NaN
# 3               Loop the Loop (Coney Island)               Edwin Prescott
# 4               Loop the Loop (Young's Pier)               Edwin Prescott
# ...                                      ...                          ...
# 1079            Ice Breaker (roller coaster)                Premier Rides
# 1081                   Leviathan (Sea World)           Martin & Vleminckx
# 1083               Pantheon (roller coaster)                      Intamin
# 1085                                 Tumbili    S&S – Sansei Technologies
# 1086          Wonder Woman Flight of Courage  Rocky Mountain Construction
#
#      Opening_Date_clean  Speed_mph  Height_ft  Year_Introduced  latitude  \
# ...

# %%
# if we use seaborn for this chart it will be more advanced in analysis 
sns.scatterplot(x='Speed_mph' , y ='Height_ft' ,data= data1)
# Out:
# <Axes: xlabel='Speed_mph', ylabel='Height_ft'>

# %%
# if we use seaborn for this chart it will be more advanced in analysis 
sns.scatterplot(x='Speed_mph' , y ='Height_ft' ,hue='Year_Introduced' , data= data1)
# Out:
# <Axes: xlabel='Speed_mph', ylabel='Height_ft'>

# %%
# using bairplot  
sns.pairplot(data = data1 , vars = ['Speed_mph','Height_ft','Year_Introduced','Inversions_clean','Gforce_clean'])

# %%
# using bairplot  
sns.pairplot(data = data1 ,hue='Status', vars = ['Speed_mph','Height_ft','Year_Introduced','Inversions_clean','Gforce_clean'])

# %%
# define the correleation between a subset of my data set

# %%
data1[['Speed_mph','Height_ft','Year_Introduced','Inversions_clean','Gforce_clean']].dropna().corr()
# Out:
#                   Speed_mph  Height_ft  Year_Introduced  Inversions_clean  \
# Speed_mph          1.000000   0.733999         0.171978         -0.028705
# Height_ft          0.733999   1.000000         0.135413         -0.079736
# Year_Introduced    0.171978   0.135413         1.000000         -0.209887
# Inversions_clean  -0.028705  -0.079736        -0.209887          1.000000
# Gforce_clean       0.607383   0.466482         0.160247          0.275991
#
#                   Gforce_clean
# Speed_mph             0.607383
# Height_ft             0.466482
# Year_Introduced       0.160247
# Inversions_clean      0.275991
# Gforce_clean          1.000000

# %%
tbl_corr = data1[['Speed_mph','Height_ft','Year_Introduced','Inversions_clean','Gforce_clean']].dropna().corr()
sns.heatmap(tbl_corr , annot=True)
# Out:
# <Axes: >

# %%
### Now it is time to answore questions about the data 
data1['Location'].value_counts()
# Out:
# Other                            181
# Kings Island                      19
# Cedar Point                       18
# Six Flags Magic Mountain          17
# Hersheypark                       16
#                                 ...
# Granada Studios Tour               1
# Funtown Splashtown USA             1
# Tolchester Beach Park              1
# Suzuka, Mie Prefecture, Japan      1
# Epcot                              1
# Name: Location, Length: 280, dtype: int64

# %%
data1.query('Location != "Other"')\
            .groupby('Location')['Speed_mph']\
            .agg(['mean' , 'count'])\
            .query('count >= 10')\
            .sort_values('mean',ascending = False)
# Out:
#                                  mean  count
# Location
# Busch Gardens Williamsburg  58.318182     11
# Cedar Point                 57.833333     18
# Six Flags Magic Mountain    57.241176     17
# Canada's Wonderland         53.533333     12
# Six Flags Great Adventure   53.036364     11
# Kings Dominion              52.083333     12
# Hersheypark                 50.576923     13
# Kings Island                49.273684     19
# Carowinds                   43.571429     14
# Alton Towers                42.791667     12

# %%
data1.query('Location != "Other"')\
            .groupby('Location')['Speed_mph']\
            .agg(['mean' , 'count'])\
            .query('count >= 10')\
            .sort_values('mean',ascending = True)['mean']\
.plot(kind='barh' ,figsize=(12,5), title = 'Most location of Speed RollerCoasters with count above of 10')
# Out:
# <Axes: title={'center': 'Most location of Speed RollerCoasters with count above of 10'}, ylabel='Location'>
